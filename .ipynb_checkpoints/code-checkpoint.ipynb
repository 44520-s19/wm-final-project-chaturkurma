# %% [markdown]
# # Name: Chatur Veda Vyas Kurma
#
# # Title: Opinion for Restaurant Reviews on food items
#
# ## 1.  What question do you want to ask?
#     Doing Sentimental analysis for the reviews given by the customers on the restaurant and determining whether the review given is a positive, negative or neutral sentiment
# ## 2.  What platform(s) will you be mining to answer this question?
#     Restaurants are customer review and product review based platforms in which we are minning for following links for retrieving the information
#     1.  https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2
#     2.  https://www.yelp.com/biz/the-house-san-francisco
#     3.  https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco
#
# ## 3. What python module(s) will you be using to retrieve your data?
#     Beautiful soup is used to retrieve the data from the webpage .Matplotlib is used to plot the graphs in 3-Dimensional, so used for ploting the sentimental analysis .requests/urllib is used to store the mined data. Pandas is used to generate the wordcloud which are most commonly used words in the reviews.
#
# ## 4. Identify some analysis techniques we've discussed in class (graph algorithms, lexical diversity, sentiment analysis) that may help you answer your question?
#     I used sentimental Analysis technique for solving the problem. Sentimental Analysis is Analysing the reviews given by the customer on the website and deciding whether that review is a positive, Negative or neutral sentiments based on the Human emotions how they reviewed.
#
# ## 5.	How might you want to visualize your data?
#     I want to visualize my data on 3-Dimensional plot as they are not only positive or negative but there are several common neutral sentiments in the reviews, so to view that all reviews i considered 3-D plot. We can also use 2-D plot for reviewing as there will only be positive and negative sentiments.

# %% [markdown]
# ## Collecting the required information
#
#     I considered Yelp.com for for doing my project as there are all the emotional reviews in site and its a top quality site for reviewing the restaurants. I took three restaurants in the san-francisco that is The Fog-harbour-fish-house, The House and Marufuku-Ramen-sf and collected the recent reviews from the webpage by using the BeautifulSoup.

# %% [markdown]
# ## Retrieving the Data of fog-harbor-fish-house

# %%
import pickle
import requests
from bs4 import BeautifulSoup 
URL= 'https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2'
page=requests.get(URL)
soup = BeautifulSoup(page.text, 'html5lib')
rest_review1 = soup.find_all('p', {'lang':'en'})
restaurant_list = ['Fog Harbor Fish House', 'The House', 'Marufuku Ramen SF', 'Zazie', 'Kitchen Story']
rest_review1_list = list()
string = ""
for i in rest_review1:
    string += i.text
    #print(i.text,'\n')
    rest_review1_list.append(i.text)

print(rest_review1_list)
# Out:
# ['Went here for lunch on a Friday to celebrate a graduation. I was really surprised to see how busy it was at noon !! Definitely recommend reservations. Food is delicious! We had the calamari, a variety of salmon dishes, the lobster roll, and some sort of bleu cheese appetizer. Drinks were great as well.', "The clam chowder was savory and delicious. I wished they had them in cans! The garlic crab was just okay. The crab was over cooked and had too much butter for me. It's been hours later and I'm still choking from the butter in my throat.", 'Visiting from Chicago. Relied on Yelp recommendations to find Fog Harbor Fish House. Reservation made for 5PM even a week in advance was a good sign for business. The restaurant was packed by the time we arrived at 450 PM.Seated by the windows with a perfect ocean view on a sunny Saturday.Cocktail shrimps were fresh and meaty. Sourdough bread was warm and soft.Clam chowder was clammy with generous portions of clam meat.Lazy cippino had fresh sea
# ...

# %% [markdown]
# ## Sentiment Analysis for fog-harbor-fish-house
#
#         Determines the positive, negative, neutral and overall compound sentiment for the review

# %%
import pickle
from nltk_helpers import get_sentiments

for empty in rest_review1_list:
    print(get_sentiments(empty))
# Out:
# {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.9677}
# {'neg': 0.059, 'neu': 0.825, 'pos': 0.116, 'compound': 0.4389}
# {'neg': 0.015, 'neu': 0.761, 'pos': 0.224, 'compound': 0.993}
# {'neg': 0.024, 'neu': 0.67, 'pos': 0.305, 'compound': 0.9862}
# {'neg': 0.07, 'neu': 0.73, 'pos': 0.2, 'compound': 0.8643}
# {'neg': 0.01, 'neu': 0.819, 'pos': 0.171, 'compound': 0.9769}
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.9639}
# {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.9777}
# {'neg': 0.078, 'neu': 0.765, 'pos': 0.157, 'compound': 0.923}
# {'neg': 0.013, 'neu': 0.732, 'pos': 0.256, 'compound': 0.9911}
# {'neg': 0.011, 'neu': 0.739, 'pos': 0.25, 'compound': 0.989}
# {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.9896}
# {'neg': 0.018, 'neu': 0.799, 'pos': 0.183, 'compound': 0.9622}
# {'neg': 0.0, 'neu': 0.554, 'pos': 0.446, 'compound': 0.9813}
# {'neg': 0.035, 'neu': 0.776, 'pos': 0.188, 'compound': 0.9969}
# ...

# %% [markdown]
# ## Sentiment Analysis graph for fog-harbor-fish-house

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#build our figure
fig = plt.figure()
# build the axes
ax = fig.add_subplot(111, projection='3d')

#add another set of data
import pickle

from nltk_helpers import split_sentiments

arbyX, arbyY, arbyZ = split_sentiments([get_sentiments(empty) for empty in rest_review1_list])
ax.scatter(arbyX, arbyY, arbyZ, color='r', marker='^')

ax.set_xlabel('Negative')
ax.set_zlabel('Neutral')
ax.set_ylabel('Positive')
ax.set_title('Sentimental Analysis Plot for fog-harbour-fish-house')
plt.show()

# %% [markdown]
# ## Retrieving the Data of The House Restaurant

# %%
import pickle
import requests
from bs4 import BeautifulSoup 
URL1= 'https://www.yelp.com/biz/the-house-san-francisco'
page1=requests.get(URL1)
soup1 = BeautifulSoup(page1.text, 'html5lib')
rest_review2 = soup1.find_all('span', {'lang':'en','class':'lemon--span__373c0__3997G'})
#print(rest_review2)
rest_review2_list = list()
for i in rest_review2:
    string += i.text
    #print(i.text,'\n')
    rest_review2_list.append(i.text)
print(rest_review2_list)
# Out:
# ["Came here on a reservation with a party of 12 and the staff was super friendly and accommodating! They had our table set up and we were promptly seated.I got to sample several items on the menu. Starting the small plates, we had the salmon rolls and octopus. Both were delicious. I highly recommend the octopus since it was perfectly cooked and juicy. The fried avocados underneath were especially delicious with the creamy sauce.For entrees, we had the curry noodles, kurobuta pork chop, and the wasabi noodles. I've never had wasabi noodles before and they weren't as spicy as I imagined. It does give you the burning sensation in your nose when you eat it too fast though. I've also heard good things about their garlic noodles.All of the proteins were SO GOOD. Everything but the shrimp was cooked medium. I really enjoyed the salmon! It was melt in your mouth. The service was prompt and the staff was very nice. We were well taken care of despite how busy it got after people started to pou
# ...

# %% [markdown]
# ## Sentiment Analysis for The House Restaurant

# %%
import pickle
from nltk_helpers import get_sentiments

for empty in rest_review2_list:
    print(get_sentiments(empty))
# Out:
# {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.9859}
# {'neg': 0.039, 'neu': 0.695, 'pos': 0.266, 'compound': 0.9939}
# {'neg': 0.043, 'neu': 0.529, 'pos': 0.427, 'compound': 0.9804}
# {'neg': 0.011, 'neu': 0.774, 'pos': 0.215, 'compound': 0.9785}
# {'neg': 0.037, 'neu': 0.766, 'pos': 0.196, 'compound': 0.9939}
# {'neg': 0.032, 'neu': 0.667, 'pos': 0.302, 'compound': 0.9974}
# {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.9826}
# {'neg': 0.049, 'neu': 0.757, 'pos': 0.194, 'compound': 0.9737}
# {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'compound': 0.9642}
# {'neg': 0.068, 'neu': 0.865, 'pos': 0.067, 'compound': -0.7646}
# {'neg': 0.04, 'neu': 0.773, 'pos': 0.187, 'compound': 0.9738}
# {'neg': 0.055, 'neu': 0.728, 'pos': 0.217, 'compound': 0.949}
# {'neg': 0.039, 'neu': 0.702, 'pos': 0.259, 'compound': 0.9988}
# {'neg': 0.023, 'neu': 0.735, 'pos': 0.242, 'compound': 0.9974}
# {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.9778}
# ...

# %% [markdown]
# ## Sentimental Analysis graph for The House

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#build our figure
fig = plt.figure()
# build the axes
ax = fig.add_subplot(111, projection='3d')

#add another set of data
import pickle

from nltk_helpers import split_sentiments

arbyX, arbyY, arbyZ = split_sentiments([get_sentiments(empty) for empty in rest_review2_list])
ax.scatter(arbyX, arbyY, arbyZ, color='b', marker='^')

ax.set_xlabel('Negative')
ax.set_zlabel('Neutral')
ax.set_ylabel('Positive')
ax.set_title('Sentimental Analysis Plot for The House')

plt.show()

# %% [markdown]
# ## Retrieving the Data of  Marufuku-Ramen-sf Restaurant

# %%
import pickle
import requests
from bs4 import BeautifulSoup 
URL2= 'https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco'
page2=requests.get(URL2)
soup2 = BeautifulSoup(page2.text, 'html5lib')
rest_review3 = soup2.find_all('p', {'lang':'en',})
#print(rest_review2)
rest_review3_list = list()
for i in rest_review3:
    string += i.text
    #print(i.text,'\n')
    rest_review3_list.append(i.text)
print(rest_review3_list)
# Out:
# ['This place is good but not worth a crazy wait. Came here because I noticed the line was short and only 20mins wait time. Sometimes I think people see the line and think "oh must be worth the wait!" IMHO if you have to wait 45mins to an hour+ do yourself a favor find somewhere else to eat. The hakata style ramen was good and hits the spot. There\'s an option with a chicken leg and I think that\'s a popular option and worth the money. I got the regular hakata tonkatsu ramen and that was delicious! Came with an egg, chaushu, and the usual veg (sprouts and scallions).', "Delicious, if slightly overrated, ramen staple of Japantown. Make sure you get the deluxe ramen, so you don't miss out on the thick cut of pork belly. Seriously, I'd inject it into my bloodstream if I could.Also, be prepared to wait. Unless you show up before the restaurant opens, you'll be quite a ways back on the waitlist.", 'Meh meh meh...overhyped. \xa0Waitlist system awesome. \xa0I think some Chinese company owns 
# ...

# %% [markdown]
# ## Sentiment Analysis for Marufuku-Ramen-sf Restaurant

# %%
import pickle
from nltk_helpers import get_sentiments

for empty in rest_review3_list:
    print(get_sentiments(empty))
# Out:
# {'neg': 0.05, 'neu': 0.772, 'pos': 0.178, 'compound': 0.9534}
# {'neg': 0.06, 'neu': 0.789, 'pos': 0.152, 'compound': 0.7011}
# {'neg': 0.099, 'neu': 0.837, 'pos': 0.065, 'compound': -0.7866}
# {'neg': 0.019, 'neu': 0.761, 'pos': 0.22, 'compound': 0.9908}
# {'neg': 0.048, 'neu': 0.725, 'pos': 0.228, 'compound': 0.997}
# {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.8442}
# {'neg': 0.04, 'neu': 0.834, 'pos': 0.127, 'compound': 0.8955}
# {'neg': 0.061, 'neu': 0.77, 'pos': 0.169, 'compound': 0.9359}
# {'neg': 0.037, 'neu': 0.806, 'pos': 0.156, 'compound': 0.9584}
# {'neg': 0.017, 'neu': 0.822, 'pos': 0.162, 'compound': 0.9839}
# {'neg': 0.097, 'neu': 0.821, 'pos': 0.082, 'compound': -0.6059}
# {'neg': 0.063, 'neu': 0.769, 'pos': 0.168, 'compound': 0.9412}
# {'neg': 0.058, 'neu': 0.78, 'pos': 0.162, 'compound': 0.9877}
# {'neg': 0.05, 'neu': 0.803, 'pos': 0.147, 'compound': 0.9849}
# {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.9482}
# ...

# %% [markdown]
# ## Sentiment Analysis graph for Marufuku-Ramen-sf Restaurant

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#build our figure
fig = plt.figure()
# build the axes
ax = fig.add_subplot(111, projection='3d')

#add another set of data
import pickle

from nltk_helpers import split_sentiments

arbyX, arbyY, arbyZ = split_sentiments([get_sentiments(empty) for empty in rest_review3_list])
ax.scatter(arbyX, arbyY, arbyZ, color='g', marker='^')

ax.set_xlabel('Negative')
ax.set_zlabel('Neutral')
ax.set_ylabel('Positive')
ax.set_title('Sentimental Analysis Plot for Marufuku-Ramen-sf')
plt.show()

# %% [markdown]
# ## Complete Sentiment Analysis graph for all reviews

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style

#build our figure
fig = plt.figure()
# build the axes
ax = fig.add_subplot(111, projection='3d')

#add another set of data

from nltk_helpers import split_sentiments
style.use('default')
arbyX, arbyY, arbyZ = split_sentiments([get_sentiments(empty) for empty in rest_review1_list])
ax.scatter(arbyX, arbyY, arbyZ, color='r', marker='^', label='fog-harbor-fish-house')

arbX, arbY, arbZ = split_sentiments([get_sentiments(empty) for empty in rest_review2_list])
ax.scatter(arbX, arbY, arbZ, color='b', marker='^', label='the-house')

arX, arY, arZ = split_sentiments([get_sentiments(empty) for empty in rest_review3_list])
ax.scatter(arX, arY, arZ, color='g', marker='^', label='marufuku-ramen-sf')

ax.set_xlabel('Negative')
ax.set_zlabel('Neutral')
ax.set_ylabel('Positive')
ax.legend()
ax.set_title('Sentimental Analysis Plot')


plt.show()

# %% [markdown]
# # Word-Cloud
#
#    Here most commonly used words in all the reviews are shown. The word used more number of times is displayed larger in size

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
words = string.lower().split()
word_count = Counter(words)
#print(word_count)
wordcloud = WordCloud(width = 1000, height = 1000, min_font_size = 10).generate(string)
plt.figure(figsize = (10, 10))
wordcloud = WordCloud(background_color='white',max_font_size = 50).generate(string)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Stop-Words

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
set(stopwords.words('english'))
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
cunt=string
stop_words = set(stopwords.words('english')) 
word_tokens = word_tokenize(cunt)
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w)
print(word_tokens) 
print(filtered_sentence)
# Out:
# ['Went', 'here', 'for', 'lunch', 'on', 'a', 'Friday', 'to', 'celebrate', 'a', 'graduation', '.', 'I', 'was', 'really', 'surprised', 'to', 'see', 'how', 'busy', 'it', 'was', 'at', 'noon', '!', '!', 'Definitely', 'recommend', 'reservations', '.', 'Food', 'is', 'delicious', '!', 'We', 'had', 'the', 'calamari', ',', 'a', 'variety', 'of', 'salmon', 'dishes', ',', 'the', 'lobster', 'roll', ',', 'and', 'some', 'sort', 'of', 'bleu', 'cheese', 'appetizer', '.', 'Drinks', 'were', 'great', 'as', 'well.The', 'clam', 'chowder', 'was', 'savory', 'and', 'delicious', '.', 'I', 'wished', 'they', 'had', 'them', 'in', 'cans', '!', 'The', 'garlic', 'crab', 'was', 'just', 'okay', '.', 'The', 'crab', 'was', 'over', 'cooked', 'and', 'had', 'too', 'much', 'butter', 'for', 'me', '.', 'It', "'s", 'been', 'hours', 'later', 'and', 'I', "'m", 'still', 'choking', 'from', 'the', 'butter', 'in', 'my', 'throat.Visiting', 'from', 'Chicago', '.', 'Relied', 'on', 'Yelp', 'recommendations', 'to', 'find', 'Fog', 'Harbor'
# ...

# %%
import io 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
stop_words = set(stopwords.words('english'))  
words = string.split() 
for r in words: 
    if not r in stop_words: 
        appendFile = open('filteredtext.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close() 

fun= open('filteredtext' , 'r')
print(fun.read())

# %% [markdown]
# ## Conclusion

# %% [markdown]
#  There was some difference in overall rating of The-house restaurant and the sentintal analysis as there are more positive components. The overall review is better for ‘marufuku-raman-sf ’is higher among all because there are more number of positive reviews given by the customer. There are more negative reviews for fog harbor fish house.3D graph is used because there are more number of neutral reviews than positive and negative. There are several common neutral words in all the reviews
